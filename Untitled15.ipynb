# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/Under-standing-data/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/web-show 250.csv',index_col=0)

# %% [markdown]
# #How big is dataset

# %%
df.shape
# Out:
# (250, 5)

# %% [markdown]
# # How does the data look like
# - first method

# %%
df.head(50)
# Out:
#                                 names relese_date run_time rating_tag  rating
# 0                        Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 1                     Planet Earth II        2016    6 eps       TV-G     9.5
# 2                        Planet Earth        2006   11 eps      TV-PG     9.4
# 3                    Band of Brothers        2001   10 eps      TV-MA     9.4
# 4                           Chernobyl        2019    5 eps      TV-MA     9.3
# 5                            The Wire   2002–2008   60 eps      TV-MA     9.3
# 6          Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 7                      Blue Planet II        2017    7 eps       TV-G     9.3
# 8                        The Sopranos   1999–2007   86 eps      TV-MA     9.2
# 9         Cosmos: A Spacetime Odyssey        2014   13 eps      TV-PG     9.2
# 10                             Cosmos        1980   13 eps      TV-PG     9.3
# ...

# %% [markdown]
# #How dataset looks like
# - second method

# %%
df.sample(10)
# Out:
#                             names relese_date run_time rating_tag  rating
# 2                    Planet Earth        2006   11 eps      TV-PG     9.4
# 78               Band of Brothers        2001   10 eps      TV-MA     9.4
# 50                   Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 17                           Life        2009   11 eps       TV-G     9.1
# 217                          Life        2009   11 eps       TV-G     9.1
# 182                Blue Planet II        2017    7 eps       TV-G     9.3
# 209   Cosmos: A Spacetime Odyssey        2014   13 eps      TV-PG     9.2
# 86                     Our Planet   2019–2023   12 eps      TV-PG     9.3
# 28               Band of Brothers        2001   10 eps      TV-MA     9.4
# 175                  Breaking Bad   2008–2013   62 eps      TV-MA     9.5

# %% [markdown]
# # What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   names        250 non-null    object
#  1   relese_date  250 non-null    object
#  2   run_time     250 non-null    object
#  3   rating_tag   250 non-null    object
#  4   rating       250 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 11.7+ KB

# %% [markdown]
# # Are there any missing values?

# %%
df.isnull().sum()
# Out:
# names          0
# relese_date    0
# run_time       0
# rating_tag     0
# rating         0
# dtype: int64

# %% [markdown]
# # How does the data look mathematically?

# %%
df.describe()
# Out:
#            rating
# count  250.000000
# mean     9.224000
# std      0.142496
# min      9.000000
# 25%      9.100000
# 50%      9.200000
# 75%      9.300000
# max      9.500000

# %% [markdown]
# # Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 225

# %% [markdown]
# # How is the corelation between cols?

# %%
df.corr() #It only performed on INT or Float.
